# %%
first_num = int(input("Enter the first number of the fibonacci series... "))
second_num = int(input("Enter the second number of the fibonacci series... "))
num_of_terms = int(input("Enter the number of terms... "))
print(first_num,second_num)
print("The numbers in fibonacci series are : ")
while(num_of_terms-2):
   third_num = first_num + second_num
   first_num=second_num
   second_num=third_num
   print(third_num)
   num_of_terms=num_of_terms-1
# Out:
# Enter the first number of the fibonacci series... 1
# Enter the second number of the fibonacci series... 45
# Enter the number of terms... 10
# 1 45
# The numbers in fibonacci series are :
# 46
# 91
# 137
# 228
# 365
# 593
# 958
# 1551

# %%
#Using Recursion
def recur_fibo(n):
    if n <= 1:
        return n
    else:
        return(recur_fibo(n-1) + recur_fibo(n-2))
nterms =int(input("Plese enter a positive integer"))
# check if the number of terms is validif nterms <= 0:
print("Fibonacci sequence:")
for i in range(nterms):
    print(recur_fibo(i))
# Out:
# Plese enter a positive integer3
# Fibonacci sequence:
# 0
# 1
# 1
